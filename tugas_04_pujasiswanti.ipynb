# %% [markdown]
# ## Biodata Diri
#
# * **Nama Lengkap: Puja Mei Siswanti**
# * **ID Telegram: @pujaorangbaik**
# * **Email: pujasiswanti@gmail.com**

# %% [markdown]
# ## Soal 1
# **Sistem Penilaian Otomatis dengan Pengetesan Kondisi**
#
# Buat sebuah script Python yang meminta pengguna memasukkan nilai siswa (dalam rentang 0-100). Program harus:
# 1. Menentukan dan mencetak grade berdasarkan kriteria berikut:
#    - Nilai >= 90: Grade A
#    - Nilai >= 80: Grade B
#    - Nilai >= 70: Grade C
#    - Nilai >= 60: Grade D
#    - Nilai < 60: Grade E
# 2. Jika nilai yang dimasukkan tidak valid (di luar rentang 0-100), tampilkan pesan error.
#
# **Pengetesan Kondisi:**
# - Input: `90`
#   Output:
#   ```
#   Grade: A
#   ```
# - Input: `65`
#   Output:
#   ```
#   Grade: D
#   ```
# - Input: `-10`
#   Output:
#   ```
#   Nilai tidak valid. Harus dalam rentang 0-100.
#   ```
#
# ---

# %%
## JAWABAN SOAL 1

nilai = int(input("Masukkan nilai siswa: "))

if nilai >= 90:
  print("Grade A")
elif nilai >= 80:
  print("Grade B")
elif nilai >= 80:
  print("Grade B")
elif nilai >= 70:
  print("Grade C")
elif nilai >= 60:
  print("Grade D")
elif 60 > nilai >= 0 :
  print("Grade E")
else:
  print("Nilai tidak valid. Harus dalam rentang 0-100.")
# Out:
# Masukkan nilai siswa: 90
# Grade A

# %%
## JAWABAN SOAL 1

nilai = int(input("Masukkan nilai siswa: "))

if nilai >= 90:
  print("Grade A")
elif nilai >= 80:
  print("Grade B")
elif nilai >= 80:
  print("Grade B")
elif nilai >= 70:
  print("Grade C")
elif nilai >= 60:
  print("Grade D")
elif 60 > nilai >= 0 :
  print("Grade E")
else:
  print("Nilai tidak valid. Harus dalam rentang 0-100.")
# Out:
# Masukkan nilai siswa: 65
# Grade D

# %%
## JAWABAN SOAL 1

nilai = int(input("Masukkan nilai siswa: "))

if nilai >= 90:
  print("Grade A")
elif nilai >= 80:
  print("Grade B")
elif nilai >= 80:
  print("Grade B")
elif nilai >= 70:
  print("Grade C")
elif nilai >= 60:
  print("Grade D")
elif 60 > nilai >= 0 :
  print("Grade E")
else:
  print("Nilai tidak valid. Harus dalam rentang 0-100.")
# Out:
# Masukkan nilai siswa: -10
# Nilai tidak valid. Harus dalam rentang 0-100.

# %% [markdown]
# ### Soal 2
# **Hitung Jumlah Huruf Vokal dan Konsonan dengan Pengetesan Kondisi**
#
# Buat script Python untuk menghitung jumlah huruf vokal dan konsonan dalam sebuah kalimat yang dimasukkan pengguna. Abaikan karakter selain huruf.
#
# **Pengetesan Kondisi:**
# 1. Input: `"Halo Dunia"`
#    Output:
#    ```
#    Jumlah huruf vokal: 5
#    Jumlah huruf konsonan: 4
#    ```
# 2. Input: `"123 AI!!"`
#    Output:
#    ```
#    Jumlah huruf vokal: 2
#    Jumlah huruf konsonan: 1
#    ```
# 3. Input: `"Python"`
#    Output:
#    ```
#    Jumlah huruf vokal: 1
#    Jumlah huruf konsonan: 5
#    ```
#
# ---

# %%
## JAWABAN SOAL 2
kalimat = input("Masukkan kalimat: ")

vokal = "aiueoAIUEO"
jml_vokal = 0
jml_konsonan = 0

for huruf in kalimat:
  if huruf.isalpha():
    if huruf in vokal:
      jml_vokal += 1
    else:
      jml_konsonan += 1

print("Jumlah huruf vokal:", jml_vokal)
print("Jumlah huruf konsonan:", jml_konsonan)
# Out:
# Masukkan kalimat: Halo Dunia
# Jumlah huruf vokal: 5
# Jumlah huruf konsonan: 4

# %%
## JAWABAN SOAL 2
kalimat = input("Masukkan kalimat: ")

vokal = "aiueoAIUEO"
jml_vokal = 0
jml_konsonan = 0

for huruf in kalimat:
  if huruf.isalpha():
    if huruf in vokal:
      jml_vokal += 1
    else:
      jml_konsonan += 1

print("Jumlah huruf vokal:", jml_vokal)
print("Jumlah huruf konsonan:", jml_konsonan)
# Out:
# Masukkan kalimat: 123 AI !!
# Jumlah huruf vokal: 2
# Jumlah huruf konsonan: 0

# %%
## JAWABAN SOAL 2
kalimat = input("Masukkan kalimat: ")

vokal = "aiueoAIUEO"
jml_vokal = 0
jml_konsonan = 0

for huruf in kalimat:
  if huruf.isalpha():
    if huruf in vokal:
      jml_vokal += 1
    else:
      jml_konsonan += 1

print("Jumlah huruf vokal:", jml_vokal)
print("Jumlah huruf konsonan:", jml_konsonan)
# Out:
# Masukkan kalimat: Python
# Jumlah huruf vokal: 1
# Jumlah huruf konsonan: 5

# %% [markdown]
# ## Soal 3
# **Simulasi Antrian dengan Pengetesan Kondisi**
#
# Simulasikan antrian sederhana menggunakan script Python. script ini harus menerima input dari pengguna untuk menambah nama ke antrian, menampilkan daftar antrian, atau menghapus nama pertama dari antrian.
#
# **Pengetesan Kondisi:**
# 1. Tambahkan pelanggan: Budi dan Siti:
#    ```python
#    Menu:
#    1. Tambahkan pelanggan ke antrian
#    2. Tampilkan daftar antrian
#    3. Layani pelanggan
#    4. Keluar
#    Pilih menu (1/2/3/4): 1
#    Masukkan nama pelanggan: Budi
#    Budi telah ditambahkan ke antrian.
#
#    Pilih menu (1/2/3/4): 1
#    Masukkan nama pelanggan: Siti
#    Siti telah ditambahkan ke antrian.
#    ```
# 2. Tampilkan daftar antrian:
#    ```python
#    Pilih menu (1/2/3/4): 2
#    Daftar antrian: ['Budi', 'Siti']
#    ```
# 3. Layani pelanggan
#    ```python
#    Pilih menu (1/2/3/4): 3
#    Pelanggan yang dilayani: Budi
#    ```
# 4. Tambahkan pelanggan: Ali dan tampilkan antrian
#    ```python
#    Pilih menu (1/2/3/4): 1
#    Masukkan nama pelanggan: Ali
#    Ali telah ditambahkan ke antrian.
#
#    Pilih menu (1/2/3/4): 2
#    Daftar antrian: ['Siti', 'Ali']
#    ```
# ---

# %%
## JAWABAN SOAL 3
antrian = []

while True:
  print("====================================")
  print("|               Menu               |")
  print("====================================")
  print("|1. Tambahkan pelanggan ke antrian |")
  print("|2. Tampilkan daftar antrian       |")
  print("|3. Layani pelanggan               |")
  print("|4. Keluar                         |")
  print("====================================")
  menu = int(input("Pilih menu (1/2/3/4): "))

  if menu == 1:
    nama_pelanggan = input("masukkan nama pelanggan: ")
    antrian.append(nama_pelanggan)
    print(nama_pelanggan, "telah ditambahkan ke antrian.")
  elif menu == 2:
    print("Daftar antrian: ", antrian)
  elif menu == 3:
    pelanggan_dilayani = antrian.pop(0)
    print("Pelanggan yang dilayani: ", pelanggan_dilayani)
  elif menu == 4:
    print("Terima kasih telah menggunakan sistem antrian.")
    break
  else:
    print("Pilihan tidak valid.")
# Out:
# ...
# |               Menu               |
# ...
# |1. Tambahkan pelanggan ke antrian |
# |2. Tampilkan daftar antrian       |
# |3. Layani pelanggan               |
# |4. Keluar                         |
# ...
# Pilih menu (1/2/3/4): 1
# masukkan nama pelanggan: Budi
# Budi telah ditambahkan ke antrian.
# ...
# |               Menu               |
# ...
# |1. Tambahkan pelanggan ke antrian |
# |2. Tampilkan daftar antrian       |
# |3. Layani pelanggan               |
# |4. Keluar                         |
# ...
# Pilih menu (1/2/3/4): 1
# masukkan nama pelanggan: Siti
# Siti telah ditambahkan ke antrian.
# ...
# |               Menu               |
# ...
# |1. Tambahkan pelanggan ke antrian |
# |2. Tampilkan daftar antrian       |
# |3. Layani pelanggan               |
# |4. Keluar                         |
# ...
# Pilih menu (1/2/3/4): 2
# Daftar antrian:  ['Budi', 'Siti']
# ...
# |               Menu               |
# ...
# |1. Tambahkan pelanggan ke antrian |
# |2. Tampilkan daftar antrian       |
# |3. Layani pelanggan               |
# ...
